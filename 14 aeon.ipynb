# %% [markdown]
# # AEON

# %% [markdown]
# В этой лекции мы более подробно поработаем с библиотекой aeon
#
# Aeon — это совместимый с scikit-learn набор инструментов для работы с временными рядами (TSML). Он организован в
# модули для различных задач обучения: классификация, регрессия, кластеризация, прогнозирование, обнаружение аномалий, сегментация и поиск по сходству.
#
# Aeon - хорошо документированная библиотека, имеет большое количество блокнотов, доступных в [документации](https://www.aeon-toolkit.org/en/stable/). Эта работа составлена на основе блокнотов, представленных в руководстве.
#
# Будем использовать для примера наборы данных ЭЭГ. Все используемые типы данных представляют собой трехмерные массивы (3D numpy arrays).

# %% [markdown]
# # Структуры данных и наборы данных
#
# *aeon* предполагает, что один временной ряд представляет собой двумерный массив формы `(n_channels, n_timepoints)`.
#
# Классификаторы и регрессоры принимают входные коллекции временных рядов (и наследуют от BaseCollectionEstimator).
#
# Если все серии имеют одинаковую длину, лучше всего работает с трехмерной фигурой `(n_cases, n_channels, n_timepoints)`.
#
# Серии разной длины хранятся в списках 2D numpy, но примеры, которые мы собираемся использовать, будут иметь одинаковую длину.
#
# В этом уроке в качестве рабочего примера будут использоваться данные ЭЭГ.
#
# Классификационный набор данных состоит из показаний ЭЭГ, снятых у испытуемого в состоянии покоя или при выполнении заданной задачи (поднятие рук). Полную информацию об этих данных можно найти в [блокноте](https://github.com/aeon-toolkit/aeon-neuro/blob/main/examples/data_loading.ipynb).
#
# *aeon* поставляется с некоторыми стандартными наборами данных UCR и UEA, и их все можно загрузить непосредственно с [timeseriesclassification.com](https://timeseriesclassification.com).

# %% [markdown]
# # Содержание
#
# * [Меры расстояний](#distance-tsc)
# * [Distance-based univariate Time Series Classification (TSC)](#classification)
# * [Distance-based  Time Series Extrinsic Regression](#regres)
# * [Подходы, основанные на свертках](#conv)
# * [Feature based classification and regression](#feature)
# * [Deep Learning подходы](#deep)
# * [Упражнения](#tasks)

# %% [markdown]
# ## Меры расстояний  <a id="distance-tsc"></a>
# Подходы, основанные на сходстве, были одним из первых предложений по классификации и регрессии временных рядов. Более того, эти типы методов также распространены для выполнения других задач временных рядов, таких как кластеризация или обнаружение аномалий и других.
#
# В первой части этой тетради представлены расстояния, реализованные в эоне, начиная с самого простого — евклидова расстояния. Затем он представляет расстояние динамического искажения времени (DTW), его варианты, такие как Amerced DTW (ADTW) или Shape DTW (ShapeDTW), а также некоторые другие альтернативные расстояния, такие как Move-Split-Merge (MSM).
#
# Во второй части этого блокнота мы демонстрируем использование этих расстояний в сочетании с классификатором KNearestNeighbours из scikit-learn, а также более подходящую реализацию KNearestNeighbours для временных рядов, включенных в aeon. Аналогичным образом также представлены подходы к работе с наборами данных TSER с использованием дистанционных подходов.
#
# Документация aeon содержит записные книжки по   [растоянию](https://www.aeon-toolkit.org/en/stable/examples/distances/distances.html) and [классификации на основе дистанции](https://www.aeon-toolkit.org/en/stable/examples/classification/distance_based.html) и искользования `aeon` расстояних с [`scikit-learn`](https://www.aeon-toolkit.org/en/stable/examples/distances/sklearn_distances.html).

# %%
# %pip install aeon[all_extras]
# %mkdir -p dataset

# %% [markdown]
# Чтобы использовать следующие команды, нужно убедиться, что wget установлен в вашей системе
# Скачать нужную версию wget можно с официального сайта  https://eternallybored.org/misc/wget/
# После скачивания - положить wget.exe сюда C:\Windows\System32
#
# Проблема windows еще и в том, что в powershell установлены allias  для iwr, curl, wget. При попытке к запустить эти команды будет запускаться виндовская Invoke-WebRequest .
# Поэтому или запускать с указанием расширения (например, wget.exe), или измненить алиас. Сделать это можно следующим образом.
#
# 1. Запускаем powershell или cmd.
#
# 2. Смотрим, что привязано к комманде wget:
# Get-Alias -Name wget
#
# 3. Если видите ответ типа "Alias           wget -> Invoke-WebRequest", то удаляем алиас:
# Remove-Item -Path Alias:\wget
#
# 4. Проверяем командой 2. Должно выдать ошибку.
#
# 5. Устанавливаем новый алиас
# New-Alias wget wget.exe
#
# Все, спокойно пользуемся привычным wget - ом.

# %%
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_MTSC_TRAIN.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_MTSC_TEST.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_UTSC_TRAIN.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_UTSC_TEST.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_MTSER_TRAIN.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_MTSER_TEST.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_UTSER_TRAIN.ts -P dataset/
# !wget -nc https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_UTSER_TEST.ts -P dataset/
# Out:
# File 'dataset/KDD_MTSC_TRAIN.ts' already there; not retrieving.
#
# --2026-01-09 20:22:08--  https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_MTSC_TEST.ts
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 366653 (358K) [text/plain]
# Saving to: 'dataset/KDD_MTSC_TEST.ts'
#
#      0K .......... .......... .......... .......... .......... 13%  108M 0s
#     50K .......... .......... .......... .......... .......... 27%  305M 0s
#    100K .......... .......... .......... .......... .......... 41%  340M 0s
#    150K .......... .......... .......... .......... .......... 55%  346M 0s
#    200K .......... .......... .......... .......... .......... 69%  326M 0s
#    250K .......... .......... .......... .......... .......... 83%  311M 0s
#    300K .......... .......... .......... .......... .......... 97%  328M 0s
#    350K ........                                              100%  158M=0,001s
#
# 2026-01-09 20:22:09 (249 MB/s) - 'dataset/KDD_MTSC_TEST.ts' saved [366653/366653]
#
# --2026-01-09 20:22:09--  https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_UTSC_TRAIN.ts
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length:
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 117424 (115K) [text/plain]
# Saving to: 'dataset/KDD_UTSER_TRAIN.ts'
#
#      0K .......... .......... .......... .......... .......... 43%  109M 0s
#     50K .......... .......... .......... .......... .......... 87%  166M 0s
#    100K .......... ....                                       100%  284M=0,001s
#
# 2026-01-09 20:22:14 (141 MB/s) - 'dataset/KDD_UTSER_TRAIN.ts' saved [117424/117424]
#
# --2026-01-09 20:22:14--  https://raw.githubusercontent.com/aeon-tutorials/KDD-2024/main/Notebooks/data/KDD_UTSER_TEST.ts
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 117219 (114K) [text/plain]
# Saving to: 'dataset/KDD_UTSER_TEST.ts'
#
#      0K .......... .......... .......... .......... .......... 43% 88,6M 0s
#     50K .......... .......... .......... .......... .......... 87%  104M 0s
#    100K .......... ....                                       100%  162M=0,001s
#
# 2026-01-09 20:22:15 (101 MB/s) - 'dataset/KDD_UTSER_TEST.ts' saved [117219/117219]

# %%
# это опционально, если хотите видеть все ворнинги - не запускайте эту ячейку

import warnings

warnings.filterwarnings("ignore")

# %%
from aeon.datasets import load_from_ts_file

# Загрузите одномерный набор данных TSC как двумерный массив NumPy

X_train_utsc, y_train_utsc = load_from_ts_file("./dataset/KDD_UTSC_TRAIN.ts", return_type="numpy2D")
X_test_utsc, y_test_utsc = load_from_ts_file("./dataset/KDD_UTSC_TEST.ts", return_type="numpy2D")

print("Single channel EEG TSC problem train shape:", X_train_utsc.shape)
print("Single channel EEG TSC problem test shape:", X_test_utsc.shape)
# Out:
# Single channel EEG TSC problem train shape: (40, 100)
# Single channel EEG TSC problem test shape: (40, 100)

# %%
# Загрузите многомерный набор данных в виде трехмерного массива numpy

X_train_mtsc, y_train_mtsc = load_from_ts_file("./dataset/KDD_MTSC_TRAIN.ts")
X_test_mtsc, y_test_mtsc = load_from_ts_file("./dataset/KDD_MTSC_TEST.ts")

print("Four channel EEG TSC problem train shape:", X_train_mtsc.shape)
print("Four channel EEG TSC problem test shape:", X_test_mtsc.shape)
# Out:
# Four channel EEG TSC problem train shape: (40, 4, 100)
# Four channel EEG TSC problem test shape: (40, 4, 100)

# %%
# Загрузите одномерный набор данных TSER как двумерный массив numpy
X_train_utser, y_train_utser = load_from_ts_file("./dataset/KDD_UTSER_TRAIN.ts", return_type="numpy2D")
X_test_utser, y_test_utser = load_from_ts_file("./dataset/KDD_UTSER_TEST.ts", return_type="numpy2D")

print("Single channel EEG TSER problem train shape:", X_train_utsc.shape)
print("Single channel EEG TSER problem test shape:", X_test_utsc.shape)
# Out:
# Single channel EEG TSER problem train shape: (40, 100)
# Single channel EEG TSER problem test shape: (40, 100)

# %%
# Загрузите многомерный набор данных TSER в виде трехмерного массива numpy
X_train_mtser, y_train_mtser = load_from_ts_file("./dataset/KDD_MTSER_TRAIN.ts")
X_test_mtser, y_test_mtser = load_from_ts_file("./dataset/KDD_MTSER_TEST.ts")

print("Four channel EEG TSER problem train shape:", X_train_mtser.shape)
print("Four channel EEG TSER problem test shape:", X_test_mtser.shape)
# Out:
# Four channel EEG TSER problem train shape: (72, 4, 100)
# Four channel EEG TSER problem test shape: (72, 4, 100)

# %% [markdown]
# Для наших примеров измерения расстояния давайте определим два разных случайных одномерных временных ряда (a и b) длиной m=10 и построим их график.

# %%
from aeon.testing.data_generation import make_example_1d_numpy
import seaborn as sns
import matplotlib.pyplot as plt

a = make_example_1d_numpy(n_timepoints=10, random_state=0)
b = make_example_1d_numpy(n_timepoints=10, random_state=1)

sns.lineplot(data=a, label=r"$\mathbf{a}$")
sns.lineplot(data=b, label=r"$\mathbf{b}$")

plt.show()

# %% [markdown]
# #### Euclidean Distance (direct alignment)

# %%
# Считаем по формуле вручную

import numpy as np

ED = np.sqrt(np.sum(np.power(a-b,2)))

print(f"The Euclidean distance between a and b is {ED}")
# Out:
# The Euclidean distance between a and b is 1.236743116180222

# %%
# Используем aeon

from aeon.distances import euclidean_distance

print(
    f"The Euclidean distance computed in aeon between a and b is",
    f"{euclidean_distance(a, b)}"
)
# Out:
# The Euclidean distance computed in aeon between a and b is 1.236743116180222

# %%
# Постройте расстояния временных рядов поточечно, следуя по пути.
def plot_time_series_distances(a, b, cost_matrix, path):
    sns.lineplot(data=a, label=r"$\mathbf{a}$")
    sns.lineplot(data=b, label=r"$\mathbf{b}$")

    # соединить точки на пути
    for i in range(len(path)):
        plt.plot(
            [path[i][0], path[i][1]],
            [a[path[i][0]], b[path[i][1]]],
            'k--',
            alpha=0.2
        )
        plt.text(
            (path[i][0]+path[i][1])/2,
            (a[path[i][0]]+b[path[i][1]])/2,
            f"{cost_matrix[path[i][0], path[i][1]]:.2f}"
        )

    return plt

# Вычислите квадрат матрицы расстояний между a и b.
def squared_pointwise_distance(a, b):
    n_timesteps = len(a)
    distances_matrix = np.zeros((n_timesteps, n_timesteps))

    for i in range(n_timesteps):
        for j in range(n_timesteps):
            distances_matrix[i, j] = (a[i]-b[j])**2

    return distances_matrix


cost_matrix = squared_pointwise_distance(a,b)
path = [(i, i) for i in range(len(a))]

ax = plot_time_series_distances(a, b, cost_matrix, path)

plt.show()

# %% [markdown]
# Евклидово расстояние также можно определить как квадратный корень из суммы квадратов разностей значений на диагонали всех возможных расстояний между элементами в обоих временных рядах.
#
# Прежде всего, мы вычисляем матрицу расстояний, которая содержит расстояния для всех элементов обоих временных рядов:

# %%
from aeon.visualisation.distances._pairwise_distance_matrix import plot_pairwise_distance_matrix

# Compute the squared pointwise distances between a and b
distance_matrix = squared_pointwise_distance(a, b)

# Draw the heatmap
ax = plot_pairwise_distance_matrix(distance_matrix, a, b, path)
plt.show()

# %% [markdown]
# #### Гибкое расстояние: динамическое искажение времени (DTW)
#  DTW допускает выравнивание по временным шагам, т. е. не обязательно выравнивать временные шаги, а только первый и последний временные шаги.
#
# В этом первом примере мы позволяем DTW иметь последовательные выравнивания, продвигающиеся не более чем на один временной шаг в каждой серии.

# %%
from aeon.distances import dtw_distance

print(
    f"The DTW distance computed in aeon between a and b is",
    f"{dtw_distance(a, b, window=0.1)}"
)
# Out:
# The DTW distance computed in aeon between a and b is 1.1985498275436108

# %%
from aeon.distances import dtw_alignment_path, dtw_cost_matrix

path, _ = dtw_alignment_path(a, b, window=0.1)
cost_matrix = dtw_cost_matrix(a, b, window=0.1)

sns.lineplot(data=a, label=r"$\mathbf{a}$")
sns.lineplot(data=b, label=r"$\mathbf{b}$")

# join the points in the path
for i in range(len(path)):
    plt.plot([path[i][0], path[i][1]], [a[path[i][0]], b[path[i][1]]], 'k--', alpha=0.2)
    plt.text(
        (path[i][0]+path[i][1])/2,
        (a[path[i][0]]+b[path[i][1]])/2,
        f"{cost_matrix[path[i][0], path[i][1]]:.2f}"
    )

plt.show()

# %% [markdown]
# Сравните графики DTW и декартового расстояния. Какие выводы?

# %% [markdown]
# Как можно заметить, теперь расстояния не вычисляются для одних и тех же моментов времени. Они
# рассчитываются с учетом коллиндантных моментов времени.
#
# В этом случае расстояние — это путь с минимальной стоимостью, который удовлетворяет вышеупомянутым условиям.
#
# Ограничения:
#
# (Обратите внимание, что для удобства чтения пути начальная позиция должна быть последней,
# в данном случае (9,9), и мы перемещаем ближайшую точку времени. Например, из (9,9) мы
# может перейти в: A) (8, 9) со стоимостью 1,32, B) (8, 8) со стоимостью 1,32 или C) (9, 8)
# со стоимостью 1,17. Последнее - правильный выбор.)

# %%
path, dtw_dist = dtw_alignment_path(a, b, window=0.1)
print(f"DTW distance between a and b is {dtw_dist}.")
# Compute the DTW cost matrix between a and b
cost_matrix = dtw_cost_matrix(a, b, window=0.1)

# Draw the heatmap
ax = plot_pairwise_distance_matrix(cost_matrix, a, b, path)
plt.show()
# Out:
# DTW distance between a and b is 1.1985498275436108.

# %% [markdown]
# Важно знать, что  DTW может быть более терпимой и предоставлять более широкие возможности выравнивания временных рядов. Чтобы контролировать такое поведение, мы определяем еще одно ограничение: размер окна.
#
# Это ограничение окон позволяет избежать выравнивания точек, разделенных более чем определенным процентом от длины временного ряда. Другими словами, если ограничение окна равно $w$, выравнивание $i$-й точки можно выполнить только с точками из интервала
#
# $[i - \lfloor w*m \rfloor, i + \lfloor w*m \rfloor]$.
#
# В предыдущем сценарии не использовался размер окна (эквивалент ограничения окна $w=1$.).
#
# Теперь, если мы уменьшим длину окна до $w=0,5$, мы увидим, что путь изменился:

# %%
w = 0.5
path, dtw_dist = dtw_alignment_path(a, b, window=w)
print(f"DTW distance with {w=} between a and b is {dtw_dist}.")

# Compute the DTW cost matrix between a and b
cost_matrix = dtw_cost_matrix(a, b, window=w)

# Draw the heatmap
ax = plot_pairwise_distance_matrix(cost_matrix, a, b, path)
plt.show()
# Out:
# DTW distance with w=0.5 between a and b is 0.8566491595090396.

# %% [markdown]
# Посмотрим, что будет при ограничении окна в 20%.

# %%
w = 0.2
path, dtw_dist = dtw_alignment_path(a, b, window=w)
print(f"DTW distance with {w=} between a and b is {dtw_dist}.")

# Compute the DTW cost matrix between a and b
cost_matrix = dtw_cost_matrix(a, b, window=w)

# Draw the heatmap
ax = plot_pairwise_distance_matrix(cost_matrix, a, b, path)
plt.show()
# Out:
# DTW distance with w=0.2 between a and b is 0.9199809594402144.

# %% [markdown]
# Можем посмотреть, какие варианты DTW реализованы в aeon. И сравнить получаемые расстояния.

# %%
from aeon.distances._distance import DISTANCES

# These are the DTW variants available in aeon for time series:
dtw_variants = [d["name"] for d in DISTANCES if 'dtw' in d["name"]]
print(f"DTW variants available in aeon: {dtw_variants}")
# Out:
# DTW variants available in aeon: ['dtw', 'dtw_gi', 'ddtw', 'wdtw', 'wddtw', 'adtw', 'shape_dtw', 'soft_dtw']

# %%
from aeon.distances import get_distance_function

for variant in dtw_variants:
    distance_function = get_distance_function(variant)
    distance = distance_function(a, b, window=0.2)
    print(f"{variant} distance between a and b is {distance}")
# Out:
# dtw distance between a and b is 0.9199809594402144
# dtw_gi distance between a and b is 0.9199809594402144
# ddtw distance between a and b is 0.31002884948727205
# wdtw distance between a and b is 0.41867594005282865
# wddtw distance between a and b is 0.13960840776560768
# adtw distance between a and b is 1.5295335354191664
# shape_dtw distance between a and b is 1.5295335354191666
# soft_dtw distance between a and b is 11.074455734012375

# %% [markdown]
# Посмотрим, какие вообще метрики расстояния раелизованы в aeon и сравним их.

# %%
for dist in DISTANCES:
    try:
        print(f"{dist['name']} distance between a and b is {dist['distance'](a, b)}")
    except TypeError as err:
        print(f"{dist['name']} - {err}")
# Out:
# euclidean distance between a and b is 1.236743116180222
# squared distance between a and b is 1.5295335354191664
# manhattan distance between a and b is 3.3323904398054873
# minkowski distance between a and b is 1.2367431161802223
# dtw distance between a and b is 0.6574923997015053
# dtw_gi distance between a and b is 0.6574923997015053
# ddtw distance between a and b is 0.31002884948727205
# wdtw distance between a and b is 0.3235461427240929
# wddtw distance between a and b is 0.13960840776560768
# lcss distance between a and b is 0.0
# erp distance between a and b is 3.021868759085019
# edr distance between a and b is 0.8
# twe distance between a and b is 6.5094056644333955
# msm distance between a and b is 3.3323904398054873
# adtw distance between a and b is 1.5295335354191664
# shape_dtw distance between a and b is 1.5295335354191666
# soft_dtw distance between a and b is 11.740090024872542
# sbd distance between a and b is 0.3633143104636234
# shift_scale distance between a and b is 0.5568073651552791
# dft_sfa - not enough arguments: expected 3, got 2
# paa_sax - not enough arguments: expected 4, got 2
# sax - not enough arguments: expected 4, got 2
# sfa - not enough arguments: expected 3, got 2
# mpdist distance between a and b is 0.0

# %% [markdown]
# # Distance-based  Time Series Classification (TSC) <a id="classification"></a>
#
# ## Univariate Time Series
#
# Одним из первых способов классификации набора временных рядов является использование k-ближайшего
# подход соседей (kNN) в сочетании с соответствующей мерой расстояния временного ряда.
#
# Самый простой способ — использовать подход kNN «scikit-learn» в сочетании с определением расстояний.
# реализовано в `aeon`. Есть два разных способа:
#
# 1. Передайте функцию расстояния как вызываемую для параметра «метрика» в конструкторе.
#
# или
#
# 2. Установите в конструкторе для метрики значение «предварительно вычисленное» и передайте попарное расстояние.
# матрица для «подгонки» и «предсказания».
#
#
#
# В этом примере мы загружаем набор данных о прицеле, используя двумерный массив numpy, который имеет два размера (n_cases, n_timepoints), учитывая, что это принятый формат `scikit-learn`.
# Несмотря на то, что `aeon` позволяет использовать 2D-массивы, обычно предпочитает 3D-массивы в форма (n_cases, n_channels, n_timepoints).

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

knn = KNeighborsClassifier(n_neighbors=3, metric=dtw_distance)
knn.fit(X_train_utsc, y_train_utsc)
predictions_utsc = knn.predict(X_test_utsc)

accuracy = accuracy_score(y_test_utsc, predictions_utsc)
print(f"Accuracy of 1-NN (sklearn) with DTW is {accuracy}")
# Out:
# Accuracy of 1-NN (sklearn) with DTW is 0.575

# %%
from aeon.classification.distance_based import KNeighborsTimeSeriesClassifier

knn_aeon = KNeighborsTimeSeriesClassifier(n_neighbors=3, distance=dtw_distance)
knn_aeon.fit(X_train_utsc, y_train_utsc)
predictions_utsc_aeon = knn_aeon.predict(X_test_utsc)

accuracy = accuracy_score(y_test_utsc, predictions_utsc_aeon)
print(f"Accuracy of 1-NN (aeon) with DTW is {accuracy}")
# Out:
# Accuracy of 1-NN (aeon) with DTW is 0.55

# %% [markdown]
# ## Distance-based Multivariate TSC (MTSC)
#
#
# Версия scikit-learn kNN не может быть применена к трехмерным массивам numpy. Однако, как мы только что видели, существует способ, которым расстояния временных рядов могут быть связаны с scikit-learn kNN: использование заранее вычисленных парных расстояний (в данном случае с расстоянием ADTW, чтобы показать разнообразие расстояний, включенных в `aeon`):

# %%
from aeon.distances import adtw_pairwise_distance, adtw_distance


train_dists = adtw_pairwise_distance(X_train_mtsc)
test_dists = adtw_pairwise_distance(X_test_mtsc, X_train_mtsc)

# scikit-learn KNN classifier with precomputed distances
knn = KNeighborsClassifier(metric="precomputed", n_neighbors=1)
knn.fit(train_dists, y_train_mtsc)
predictions_mtsc = knn.predict(test_dists)

print(
    f"Accuracy of 1-NN (sklearn) with ADTW using precomputed distances is",
    f"{accuracy_score(y_test_mtsc, predictions_mtsc)}"
)
# Out:
# Accuracy of 1-NN (sklearn) with ADTW using precomputed distances is 0.525

# %% [markdown]
# Теперь, если мы запустим подход kNN, специфичный для временных рядов, включенный в `aeon`, нам не нужно предварительно вычислять матрицу попарных расстояний, которая иногда может требовать больших вычислительных ресурсов и памяти.
#
# Для тех расстояний, которые уже реализованы в `aeon`, мы можем использовать их идентификатор вместо вызываемого расстояния. Например, расстояние ADTW обозначается как `adtw`.

# %%
knn_aeon = KNeighborsTimeSeriesClassifier(n_neighbors=1, distance=adtw_distance)
knn_aeon.fit(X_train_mtsc, y_train_mtsc)
predictions_mtsc_aeon = knn_aeon.predict(X_test_mtsc)

accuracy = accuracy_score(y_test_mtsc, predictions_mtsc_aeon)
print(f"Accuracy of 1-NN (aeon) with ADTW is {accuracy}")
# Out:
# Accuracy of 1-NN (aeon) with ADTW is 0.525

# %%
knn_aeon = KNeighborsTimeSeriesClassifier(n_neighbors=1, distance="adtw")
knn_aeon.fit(X_train_mtsc, y_train_mtsc)
predictions_mtsc_aeon = knn_aeon.predict(X_test_mtsc)

accuracy = accuracy_score(y_test_mtsc, predictions_mtsc_aeon)
print(f"Accuracy of 1-NN (aeon) with ADTW is {accuracy}")
# Out:
# Accuracy of 1-NN (aeon) with ADTW is 0.525

# %% [markdown]
# # Distance-based  Time Series Extrinsic Regression <a id='regres'></a>
#
# ## Univariate Time Series Extrinsic Regression (TSER)
#
# Рассмотрим два подхода к регрессии на основе двух метрик расстояния MSM и TWE.

# %%
from aeon.distances import (
    msm_pairwise_distance,
    twe_pairwise_distance,
)
from aeon.regression.distance_based import KNeighborsTimeSeriesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

train_dists = msm_pairwise_distance(X_train_utser)
test_dists = msm_pairwise_distance(X_test_utser, X_train_utser)
knn = KNeighborsRegressor(n_neighbors=1, metric="precomputed")
knn.fit(train_dists, y_train_utser)
predictions_utser = knn.predict(test_dists)

mse = mean_squared_error(y_test_utser, predictions_utser)
print(f"MSE of 1-NN (sklearn) with MSM is {mse}")

knn_aeon = KNeighborsTimeSeriesRegressor(n_neighbors=1, distance="msm")
knn_aeon.fit(X_train_utser, y_train_utser)
predictions_utser_aeon = knn_aeon.predict(X_test_utser)

mse = mean_squared_error(y_test_utser, predictions_utser_aeon)
print(f"MSE of 1-NN (aeon) with MSM is {mse}")
# Out:
# MSE of 1-NN (sklearn) with MSM is 1.3942060469112671
# MSE of 1-NN (aeon) with MSM is 1.3942060469112671

# %%
# Now, for the TWE distance:
train_dists = twe_pairwise_distance(X_train_utser, window=0.1)
test_dists = twe_pairwise_distance(X_test_utser, X_train_utser, window=0.1)
knn = KNeighborsRegressor(n_neighbors=1, metric="precomputed")
knn.fit(train_dists, y_train_utser)
predictions_utser = knn.predict(test_dists)

mse = mean_squared_error(y_test_utser, predictions_utser)
print(f"MSE of 1-NN (sklearn) with TWE is {mse}")

knn_aeon = KNeighborsTimeSeriesRegressor(
    n_neighbors=1,
    distance="twe",
    distance_params={"window": 0.1}
)
knn_aeon.fit(X_train_utser, y_train_utser)
predictions_utser_aeon = knn_aeon.predict(X_test_utser)

mse = mean_squared_error(y_test_utser, predictions_utser_aeon)
print(f"MSE of 1-NN (aeon) with TWE is {mse}")
# Out:
# MSE of 1-NN (sklearn) with TWE is 1.7049822984745453
# MSE of 1-NN (aeon) with TWE is 1.7049822984745453

# %% [markdown]
# ## Distance-based Multivariate TSER (MTSER)

# %%
from aeon.distances import (
    erp_pairwise_distance,
    wdtw_pairwise_distance,
)
from aeon.regression.distance_based import KNeighborsTimeSeriesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error


train_dists = erp_pairwise_distance(X_train_mtser)
test_dists = erp_pairwise_distance(X_test_mtser, X_train_mtser)
knn = KNeighborsRegressor(n_neighbors=1, metric="precomputed")
knn.fit(train_dists, y_train_mtser)
predictions_mtser = knn.predict(test_dists)

mse = mean_squared_error(y_test_mtser, predictions_mtser)
print(f"MSE of 1-NN (sklearn) with ERP is {mse}")

knn_aeon = KNeighborsTimeSeriesRegressor(n_neighbors=1, distance="erp")
knn_aeon.fit(X_train_mtser, y_train_mtser)
predictions_mtser_aeon = knn_aeon.predict(X_test_mtser)

mse = mean_squared_error(y_test_mtser, predictions_mtser_aeon)
print(f"MSE of 1-NN (aeon) with ERP is {mse}")
# Out:
# MSE of 1-NN (sklearn) with ERP is 1.0155583588945694
# MSE of 1-NN (aeon) with ERP is 1.0155583588945694

# %%
# Now, for the wdtw distance:
train_dists = wdtw_pairwise_distance(X_train_mtser, window=0.1)
test_dists = wdtw_pairwise_distance(X_test_mtser, X_train_mtser, window=0.1)
knn = KNeighborsRegressor(n_neighbors=1, metric="precomputed")
knn.fit(train_dists, y_train_mtser)
predictions_mtser = knn.predict(test_dists)

mse = mean_squared_error(y_test_mtser, predictions_mtser)
print(f"MSE of 1-NN (sklearn) with WDTW is {mse}")

knn_aeon = KNeighborsTimeSeriesRegressor(
    n_neighbors=1,
    distance="wdtw",
    distance_params={"window": 0.1}
)
knn_aeon.fit(X_train_mtser, y_train_mtser)
predictions_mtser_aeon = knn_aeon.predict(X_test_mtser)

mse = mean_squared_error(y_test_mtser, predictions_mtser_aeon)
print(f"MSE of 1-NN (aeon) with WDTW is {mse}")
# Out:
# MSE of 1-NN (sklearn) with WDTW is 1.3909486821400647
# MSE of 1-NN (aeon) with WDTW is 1.3909486821400647

# %% [markdown]
# ## Elastic Ensemble (EE) и Proximity Forest (PF)
#
# Другими более продвинутыми подходами являются EE и PF.
#
# EE представляет собой взвешенный ансамбль из 11 классификаторов 1-NN с рядом эластичных мер расстояния. Это требует перекрестной проверки весов каждого классификатора в ансамбле.
#
# В случае PF алгоритм представляет собой ансамбль высокорандомизированных деревьев близости, которые разветвляются по близости временных рядов к тому или иному образцовому временному ряду, а не по значениям атрибутов.

# %%
from aeon.classification.distance_based import ElasticEnsemble

ee = ElasticEnsemble(
    proportion_of_param_options=0.1,
    proportion_train_in_param_finding=0.3,
    proportion_train_for_test=0.5,
)
ee.fit(X_train_utsc, y_train_utsc)
ee_preds = ee.predict(X_test_utsc)

accuracy = accuracy_score(y_test_utsc, ee_preds)
print(f"Accuracy of Elastic Ensemble is {accuracy}.")
# Out:
# Accuracy of Elastic Ensemble is 0.5.

# %% [markdown]
# Более конкретно, реализация EE в `aeon` позволяет выбирать заданные меры расстояния для построения ансамбля, а также изменять некоторые параметры процедуры перекрестной проверки:

# %%
ee = ElasticEnsemble(
    distance_measures=["dtw", "msm"],
    proportion_of_param_options=0.1,
    proportion_train_in_param_finding=0.3,
    proportion_train_for_test=0.5,
)
ee.fit(X_train_utsc, y_train_utsc)
ee_preds = ee.predict(X_test_utsc)

accuracy = accuracy_score(y_test_utsc, ee_preds)
print(f"Accuracy of Elastic Ensemble with DTW and MSM is {accuracy}.")
# Out:
# Accuracy of Elastic Ensemble with DTW and MSM is 0.55.

# %% [markdown]
# Подход PF недавно был включен в `aeon` и на данный момент может решать только одномерные задачи TSC:

# %%
from aeon.classification.distance_based import ProximityForest

pf = ProximityForest(n_trees=10, random_state=0)
pf.fit(X_train_utsc, y_train_utsc)
pf_preds = pf.predict(X_test_utsc)

accuracy = accuracy_score(y_test_utsc, pf_preds)
print(f"Accuracy of Proximity Forest is {accuracy}.")
# Out:
# Accuracy of Proximity Forest is 0.525.

# %% [markdown]
# # Подходы, основанные на свертках <a id='conv'></a>
#
# ### Rocket
#
# RocketClassifier()
# Rocket — оригинальный сверточный метод классификации временных рядов.
#
# ### MiniRocket
# RocketClassifier(rocket_transform = "minirocket") — модификация Rocket, более точная.
#
# ###  Hydra
# HydraClassifier()
# HydraRegressor()
#
# Hydra — это вариант Rocket, который объединяет функции и методы подходов на основе словаря.
#
# Примечание. Гидра реализована с использованием torch. Для запуска этого кода вам понадобится установить его.
# pip install torch.
#
#
# ###  MultiRocket+Hydra
# MultiRocketHydraClassifier()
# MultiRocket+Hydra сочетает в себе подходы MultiRocket и Hydra.

# %%
from aeon.classification.convolution_based import RocketClassifier

classifier = RocketClassifier( n_jobs=-1, random_state=42)
classifier.fit(X_train_mtsc, y_train_mtsc)
classifier.score(X_test_mtsc, y_test_mtsc)
# Out:
# 0.425

# %%
from aeon.classification.convolution_based import MiniRocketClassifier

classifier = MiniRocketClassifier( n_jobs=-1, random_state=42)
classifier.fit(X_train_mtsc, y_train_mtsc)
classifier.score(X_test_mtsc, y_test_mtsc)
# Out:
# 0.9

# %%
from aeon.classification.convolution_based import  HydraClassifier

classifier = HydraClassifier( n_jobs=-1, random_state=42)
classifier.fit(X_train_mtsc, y_train_mtsc)
classifier.score(X_test_mtsc, y_test_mtsc)
# Out:
# 0.925

# %%
from aeon.classification.convolution_based import  MultiRocketHydraClassifier

classifier = MultiRocketHydraClassifier( n_jobs=-1, random_state=42)
classifier.fit(X_train_mtsc, y_train_mtsc)
classifier.score(X_test_mtsc, y_test_mtsc)
# Out:
# 0.875

# %%
from aeon.regression.convolution_based import MiniRocketRegressor
from sklearn.metrics import r2_score

regressor = MiniRocketRegressor(n_jobs=-1, random_state=42)
regressor.fit(X_train_mtser, y_train_mtser)
preds = regressor.predict(X_test_mtser)
r2_score(y_test_mtser, preds)
# Out:
# 0.4110569698148919

# %%
from aeon.visualisation import plot_scatter_predictions

plot_scatter_predictions(y_test_mtser, preds)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: xlabel='Actual values', ylabel='Predicted values'>)

# %%
# FineTuning parameters 

from sklearn.model_selection import GridSearchCV
import numpy as np
import matplotlib.pyplot as plt
from aeon.regression.convolution_based import MiniRocketRegressor

# ==============================================================================
# == fit =======================================================================
# ==============================================================================

param_grid = {
    "n_kernels" : [100, 1000, 10000],
    "max_dilations_per_kernel" : [16, 32, 64],
}

gs = GridSearchCV(
    MiniRocketRegressor(n_jobs=-1, random_state=42),
    param_grid,
)
gs.fit(X_train_mtser, y_train_mtser)

# ==============================================================================
# == plot results ==============================================================
# ==============================================================================

_scores = gs.cv_results_["mean_test_score"]
_params = np.array([f"d={_[0]}\nk={_[1]}" for _ in [tuple(_.values()) for _ in gs.cv_results_["params"]]])
_order = _scores.argsort()
_, a = plt.subplots(1, 1, figsize = (6, 4))
a.plot(_params[_order], _scores[_order], ".-")
a.set(xlabel = "d/k", ylabel = "r2")
plt.show()

# %%
# считаем скор для лучшей конфигурации
gs.score(X_test_mtser, y_test_mtser)
# Out:
# 0.39129226372986503

# %%
# смотри лучший набор

gs
# Out:
# GridSearchCV(estimator=MiniRocketRegressor(n_jobs=-1, random_state=42),
#              param_grid={'max_dilations_per_kernel': [16, 32, 64],
#                          'n_kernels': [100, 1000, 10000]})

# %% [markdown]
# # Feature based classification and regression <a id='feature'></a>
#
# Классификаторы и регрессоры на основе признаков являются популярной темой в классификации временных рядов (TSC) и регрессии (TSER).  В пригципе все такие модели представляют собой пайплайны из вытаскивателей фич и классификаторов/регрессоров.
#
# <img src="data/aeon/pipeline.png" alt="Pipeline classifier."><img>

# %%
# отрисуем наши данные 

from aeon.visualisation import plot_collection_by_class

plot_collection_by_class(X_train_mtsc[:,2,:], y_train_mtsc)
# Out:
# (<Figure size 1200x600 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %%
from matplotlib import pyplot as plt

plt.plot(X_train_mtser[0].T)
plt.legend(["Dim 0", "Dim 1", "Dim 2", "Dim 3"])

# %% [markdown]
# ## Catch22 <a id='catch22'></a>
#
# Набор инструментов для сравнительного анализа временных рядов (hctsa) может создать более 7700 функций для исследовательского анализа временных рядов. К сожалению, в настоящее время в Python не существует полного набора этих функций, заинтересованные пользователи могут ознакомиться с соответствующей публикацией и исходным набором инструментов MATLAB.
#
# Канонические характеристики временных рядов (Catch22) представляют собой 22 характеристики hctsa, которые считаются наиболее дискриминационными из полного набора.
#
# Функции Catch22 были выбраны путем оценки наборов данных UCR. Характеристики hctsa изначально были сокращены: были удалены те, которые чувствительны к среднему значению и дисперсии, а также те, которые невозможно вычислить для более чем 80 % наборов данных UCR. Затем была проведена оценка функций на основе прогнозируемой производительности. Любые функции, производительность которых была ниже порогового значения, были удалены. Для остальных признаков была выполнена иерархическая кластеризация корреляционной матрицы для устранения избыточности. Из каждого из 22 сформированных кластеров был выбран один признак с учетом сбалансированной точности, вычислительной эффективности и интерпретируемости. Функции Catch22 охватывают широкий спектр понятий, таких как базовая статистика значений рядов данных, линейные корреляции и энтропия.
#
#
# <img src="data/aeon/catch22.png" alt="Catch22 extraction process."></img>

# %% [markdown]
# Класс Catch22 преобразует временные ряды в 22 признака.

# %%
from aeon.transformations.collection.feature_based import Catch22


c22 = Catch22()
c22.fit_transform(X_train_mtsc)[:5]
# Out:
# array([[-4.94433107e-06,  6.92507633e-06,  2.98422388e+00,
#          4.00000000e+00, -8.88178420e-16, -1.01000518e-15,
#          0.00000000e+00,  1.60000000e+01,  1.11111111e-01,
#          0.00000000e+00,  0.00000000e+00,  3.00000000e+00,
#          3.84615385e-02, -2.70000000e-01,  5.30000000e-01,
#          1.57359203e-10,  5.00000000e+00,  2.00785293e+00,
#          8.28571429e-01,  6.00000000e-01,  4.90873852e-01,
#          1.40193684e-05,  1.81815758e-06, -1.47671393e-06,
#          3.71562980e+00,  4.00000000e+00, -8.88178420e-16,
#         -5.87837340e-16,  0.00000000e+00,  1.70000000e+01,
#          6.25000000e-02,  0.00000000e+00,  0.00000000e+00,
#          3.00000000e+00,  4.54545455e-02, -2.30000000e-01,
#  'CO_Embed2_Dist_tau_d_expfit_meandiff',
#  'IN_AutoMutualInfoStats_40_gaussian_fmmi',
#  'FC_LocalSimple_mean1_tauresrat',
#  'DN_OutlierInclude_p_001_mdrmd',
#  'DN_OutlierInclude_n_001_mdrmd',
#  'SP_Summaries_welch_rect_area_5_1',
#  'SB_BinaryStats_diff_longstretch0',
#  'SB_MotifThree_quantile_hh',
#  'SC_FluctAnal_2_rsrangefit_50_1_logi_prop_r1',
#  'SC_FluctAnal_2_dfa_50_1_2_logi_prop_r1',
#  'SP_Summaries_welch_rect_centroid',
#  'FC_LocalSimple_mean3_stderr']

# %% [markdown]
# Преобразование можно настроить, и вы можете выбрать подмножество функций для извлечения. Параметр catch24 будет включать среднее и стандартное отклонение, а также исходные 22 функции.
#
# pycatch22 будет использовать библиотеку pycatch22, завернутую в C.

# %%
c22 = Catch22(
    features=["DN_HistogramMode_5", "CO_f1ecac", "SB_MotifThree_quantile_hh", "Mean", "StandardDeviation"],
    catch24=True,
)
c22.fit_transform(X_train_mtsc)[:5]
# Out:
# array([[-4.94433107e-06,  2.98422388e+00,  2.00785293e+00,
#         -4.84662295e-06,  1.63624369e-05,  1.81815758e-06,
#          3.71562980e+00,  2.00199666e+00,  4.07268745e-07,
#          1.16629572e-05, -6.81925616e-06,  2.54465362e+00,
#          1.84997494e+00, -2.73869572e-06,  1.30628441e-05,
#         -4.28629432e-06,  2.25468230e+00,  1.94369228e+00,
#         -3.51260400e-06,  8.11090668e-06],
#        [-4.93347026e-07,  9.76550866e-01,  2.08655852e+00,
#          1.43118551e-06,  1.57514418e-05,  1.06128379e-06,
#          2.99539703e+00,  2.05946536e+00,  4.93131265e-06,
#          1.18989896e-05, -9.48719145e-06,  1.78980033e+00,
#          1.96831980e+00, -3.01206374e-06,  1.42330289e-05,
#         -2.88989693e-06,  2.21747187e+00,  2.04733206e+00,
#         -2.96546855e-06,  8.23176010e-06],
#        [-6.72778723e-06,  8.30813700e-01,  2.17460531e+00,
#         -6.06350354e-07,  1.33059491e-05, -1.44995057e-06,
#          7.17005807e-01,  2.16552480e+00,  3.79695308e-06,
#          1.00766877e-05, -1.83019499e-06,  2.41674894e+00,
#          1.94369228e+00,  3.37033758e-06,  1.24823971e-05,
#         -3.71330823e-06,  2.58492491e+00,  1.97770999e+00,
#          8.40880283e-07,  8.31148145e-06],
#        [ 1.06707589e-06,  9.40987016e-01,  2.16264604e+00,
#         -2.17892949e-07,  1.41719989e-05, -1.24257183e-06,
#          2.94247757e+00,  1.92542785e+00, -2.02235649e-06,
#          1.04135837e-05, -4.34236854e-06,  2.63896118e+00,
#          2.00650422e+00, -2.30261793e-06,  1.08641355e-05,
#         -3.57222777e-06,  3.04652712e+00,  2.04099986e+00,
#         -2.96036604e-06,  7.47429838e-06],
#        [ 5.41709902e-06,  8.54785389e-01,  2.15525567e+00,
#          3.07705341e-06,  1.41351503e-05, -5.96238663e-07,
#          7.96695469e-01,  2.14756047e+00,  8.81621473e-09,
#          1.01270483e-05,  5.73291371e-06,  1.59802527e+00,
#          2.11236435e+00,  2.83706608e-06,  1.17155555e-05,
#         -1.88620306e-07,  1.46937513e+00,  2.03344937e+00,
#         -8.22774051e-07,  7.29112178e-06]])

# %% [markdown]
# Классы Catch22Classifier и Catch22Regressor в aeon — это просто удобные оболочки для конвейера преобразования Catch22 и случайного леса, обучаемого scikit-learn по умолчанию.

# %%
from aeon.classification.feature_based import Catch22Classifier
from sklearn.metrics import accuracy_score

c22_cls = Catch22Classifier(random_state=42)
c22_cls.fit(X_train_mtsc, y_train_mtsc)
c22_preds_c = c22_cls.predict(X_test_mtsc)
accuracy_score(y_test_mtsc, c22_preds_c)
# Out:
# 0.9

# %%
from aeon.classification.sklearn import RotationForestClassifier

c22_cls = Catch22Classifier(
    features=["DN_HistogramMode_5", "CO_f1ecac", "SB_MotifThree_quantile_hh", "Mean", "StandardDeviation"],
    estimator=RotationForestClassifier(),
    random_state=42,
)
c22_cls.fit(X_train_mtsc, y_train_mtsc)
c22_preds_c = c22_cls.predict(X_test_mtsc)
accuracy_score(y_test_mtsc, c22_preds_c)
# Out:
# 0.9

# %%
from aeon.regression.feature_based import Catch22Regressor
from sklearn.metrics import mean_squared_error

c22_reg = Catch22Regressor(random_state=42)
c22_reg.fit(X_train_mtser, y_train_mtser)
c22_preds_r = c22_reg.predict(X_test_mtser)
mean_squared_error(y_test_mtser, c22_preds_r)
# Out:
# 0.7975235446926242

# %%
from aeon.visualisation import plot_scatter_predictions

plot_scatter_predictions(y_test_mtser, c22_preds_r)
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: xlabel='Actual values', ylabel='Predicted values'>)

# %% [markdown]
# # Deep Leaning подходы <a id='deep'></a>
#
# Можно сказать, что на данном этапе модели глубокого обучения являются SOTA моделями для решения задач классификации и регрессии временных рядов.
#
#
# <img src="data/aeon/deep-legend.png" alt="Deep Legend."></img>

# %%
# Для классификации
# нормализуем по среднему и дисперсии наши ряды 
X_train_c = (X_train_mtsc - X_train_mtsc.mean(axis=-1, keepdims=True)) / (X_train_mtsc.std(axis=-1, keepdims=True))
X_test_c = (X_test_mtsc - X_test_mtsc.mean(axis=-1, keepdims=True)) / (X_test_mtsc.std(axis=-1, keepdims=True))

print("Train shape:", X_train_c.shape)
print("Test shape:", X_test_c.shape)
# Out:
# Train shape: (40, 4, 100)
# Test shape: (40, 4, 100)

# %%
from aeon.visualisation import plot_collection_by_class

plot_collection_by_class(X_train_c[:,0,:], y_train_mtsc)
# Out:
# (<Figure size 1200x600 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %%
# для регрессии

# znormalize the series
X_train_r = (X_train_mtser - X_train_mtser.mean(axis=-1, keepdims=True)) / (X_train_mtser.std(axis=-1, keepdims=True))
X_test_r = (X_test_mtser - X_test_mtser.mean(axis=-1, keepdims=True)) / (X_test_mtser.std(axis=-1, keepdims=True))

print("Train shape:", X_train_mtser.shape)
print("Test shape:", X_test_mtser.shape)
# Out:
# Train shape: (72, 4, 100)
# Test shape: (72, 4, 100)

# %%
from matplotlib import pyplot as plt

plt.plot(X_train_r[:5,0,:].T)
plt.title("EEG Regression Samples")
plt.xlabel("Time")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# ## Multi Layer Perceptron (MLP)
#
#
# Многослойный персептрон (MLP), простейшая модель нейронных сетей, часто используется в качестве основы для моделей глубокого обучения. Однако применительно к данным временных рядов он не учитывает временные зависимости. Модель MLP пытается найти оптимальную нелинейную комбинацию входных функций для достижения хорошей производительности последующей задачи.
#
# <img src="data/aeon/MLP.png" alt="mlp"><i>

# %%
from aeon.classification.deep_learning import MLPClassifier
from sklearn.metrics import accuracy_score

mlp_cls = MLPClassifier(n_epochs=100)
mlp_cls.fit(X_train_c, y_train_mtsc)
mlp_cls_preds = mlp_cls.predict(X_test_c)
print(accuracy_score(y_test_mtsc, mlp_cls_preds))
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 0.6

# %%
from aeon.regression.deep_learning import MLPRegressor
from sklearn.metrics import mean_squared_error

mlp_rgs = MLPRegressor(n_epochs=500)
mlp_rgs.fit(X_train_r, y_train_mtser)
mlp_rgs_preds = mlp_rgs.predict(X_test_r)
print(mean_squared_error(y_test_mtser, mlp_rgs_preds))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1.6171353181226782

# %%
from aeon.visualisation import plot_scatter_predictions

plot_scatter_predictions(y_test_mtser, mlp_rgs_preds, title="MLP Predictions")
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'MLP Predictions'}, xlabel='Actual values', ylabel='Predicted values'>)

# %% [markdown]
# ## The Fully Convolutional Neural Network (FCNRegressor)
#
#
# Полностью сверточные нейронные сети (FCN) все чаще используются для анализа временных рядов благодаря их способности эффективно улавливать локальные закономерности и многомасштабные зависимости.
#
# Сверточная нейронная сеть по времени (TimeCNN) — это сверточная нейронная сеть, в которой процесс оптимизации фокусируется на изучении наиболее эффективных фильтров для достижения оптимальных результатов. В отличие от MLP, TimeCNN использует локальные свертки, позволяя улавливать и учитывать временные зависимости в данных, что делает их более подходящими для анализа временных рядов.
#
# <img src="data/aeon/TimeCNN.png" alt="cnn"><i>

# %%
from aeon.classification.deep_learning import FCNClassifier
from sklearn.metrics import accuracy_score

# n_epochs chooses the number of training iterations
# verbose show the network's detail and the logs of training
cnn_cls = FCNClassifier(n_epochs=500, verbose=True, save_best_model=True, best_file_name="best_cnn")
cnn_cls.fit(X_train_c, y_train_mtsc)
cnn_cls_preds = cnn_cls.predict(X_test_c)
print(accuracy_score(y_test_mtsc, cnn_cls_preds))
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 100, 4)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 100, 128)       │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 100, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 100, 256)       │       164,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 100, 128)       │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 100, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_1      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 269,058 (1.03 MB)
#  Trainable params: 268,034 (1.02 MB)
#  Non-trainable params: 1,024 (4.00 KB)
# Epoch 1/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6250 - loss: 0.5994 - learning_rate: 0.0010
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9250 - loss: 0.2128 - learning_rate: 0.0010
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9750 - loss: 0.1078 - learning_rate: 0.0010
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0590 - learning_rate: 0.0010
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0378 - learning_rate: 0.0010
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0264 - learning_rate: 0.0010
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.0200 - learning_rate: 0.0010
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0159 - learning_rate: 0.0010
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0130 - learning_rate: 0.0010
# Epoch 10/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0111 - learning_rate: 0.0010
# Epoch 11/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0095 - learning_rate: 0.0010
# Epoch 12/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0084 - learning_rate: 0.0010
# Epoch 13/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0075 - learning_rate: 0.0010
# Epoch 14/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0068 - learning_rate: 0.0010
# Epoch 15/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0062 - learning_rate: 0.0010
# Epoch 16/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0057 - learning_rate: 0.0010
# Epoch 17/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0053 - learning_rate: 0.0010
# Epoch 18/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0049 - learning_rate: 0.0010
# Epoch 19/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0046 - learning_rate: 0.0010
# Epoch 20/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.0043 - learning_rate: 0.0010
# Epoch 21/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0041 - learning_rate: 0.0010
# Epoch 22/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0039 - learning_rate: 0.0010
# Epoch 23/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0037 - learning_rate: 0.0010
# Epoch 24/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0035 - learning_rate: 0.0010
# Epoch 25/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0034 - learning_rate: 0.0010
# Epoch 26/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0032 - learning_rate: 0.0010
# Epoch 27/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0031 - learning_rate: 0.0010
# Epoch 28/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0030 - learning_rate: 0.0010
# Epoch 29/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0028 - learning_rate: 0.0010
# Epoch 30/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0027 - learning_rate: 0.0010
# Epoch 31/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0026 - learning_rate: 0.0010
# Epoch 32/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0026 - learning_rate: 0.0010
# Epoch 33/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0025 - learning_rate: 0.0010
# Epoch 34/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0024 - learning_rate: 0.0010
# Epoch 35/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0023 - learning_rate: 0.0010
# Epoch 36/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.0023 - learning_rate: 0.0010
# Epoch 37/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0022 - learning_rate: 0.0010
# Epoch 38/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0021 - learning_rate: 0.0010
# Epoch 39/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0021 - learning_rate: 0.0010
# Epoch 40/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0020 - learning_rate: 0.0010
# Epoch 41/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0020 - learning_rate: 0.0010
# Epoch 42/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0019 - learning_rate: 0.0010
# Epoch 43/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0019 - learning_rate: 0.0010
# Epoch 44/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0018 - learning_rate: 0.0010
# Epoch 45/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0018 - learning_rate: 0.0010
# Epoch 46/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0017 - learning_rate: 0.0010
# Epoch 47/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0017 - learning_rate: 0.0010
# Epoch 48/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0016 - learning_rate: 0.0010
# Epoch 49/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0016 - learning_rate: 0.0010
# Epoch 50/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 1.0000 - loss: 0.0016 - learning_rate: 0.0010
# Epoch 51/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0015 - learning_rate: 0.0010
# Epoch 52/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0015 - learning_rate: 0.0010
# Epoch 53/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0015 - learning_rate: 0.0010
# Epoch 54/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0014 - learning_rate: 0.0010
# Epoch 55/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0014 - learning_rate: 0.0010
# Epoch 56/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0014 - learning_rate: 0.0010
# Epoch 57/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0014 - learning_rate: 0.0010
# Epoch 58/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0013 - learning_rate: 0.0010
# Epoch 59/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0013 - learning_rate: 0.0010
# Epoch 60/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0013 - learning_rate: 0.0010
# Epoch 61/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0013 - learning_rate: 0.0010
# Epoch 62/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0012 - learning_rate: 0.0010
# Epoch 63/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0012 - learning_rate: 0.0010
# Epoch 64/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0012 - learning_rate: 0.0010
# Epoch 65/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0012 - learning_rate: 0.0010
# Epoch 66/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0012 - learning_rate: 0.0010
# Epoch 67/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0011 - learning_rate: 0.0010
# Epoch 68/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0011 - learning_rate: 0.0010
# Epoch 69/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0011 - learning_rate: 0.0010
# Epoch 70/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0011 - learning_rate: 0.0010
# Epoch 71/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0011 - learning_rate: 0.0010
# Epoch 72/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0010 - learning_rate: 0.0010
# Epoch 73/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0010 - learning_rate: 0.0010
# Epoch 74/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0010 - learning_rate: 0.0010
# Epoch 75/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 9.9348e-04 - learning_rate: 0.0010
# Epoch 76/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 9.7824e-04 - learning_rate: 0.0010
# Epoch 77/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 9.6339e-04 - learning_rate: 0.0010
# Epoch 78/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 9.4891e-04 - learning_rate: 0.0010
# Epoch 79/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 9.3480e-04 - learning_rate: 0.0010
# Epoch 80/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 9.2105e-04 - learning_rate: 0.0010
# Epoch 81/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 9.0762e-04 - learning_rate: 0.0010
# Epoch 82/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 8.9452e-04 - learning_rate: 0.0010
# Epoch 83/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 8.8173e-04 - learning_rate: 0.0010
# Epoch 84/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 8.6927e-04 - learning_rate: 0.0010
# Epoch 85/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 8.5711e-04 - learning_rate: 0.0010
# Epoch 86/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 8.4520e-04 - learning_rate: 0.0010
# Epoch 87/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 8.3359e-04 - learning_rate: 0.0010
# Epoch 88/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 8.2223e-04 - learning_rate: 0.0010
# Epoch 89/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 8.1113e-04 - learning_rate: 0.0010
# Epoch 90/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 8.0028e-04 - learning_rate: 0.0010
# Epoch 91/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 7.8966e-04 - learning_rate: 0.0010
# Epoch 92/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 7.7926e-04 - learning_rate: 0.0010
# Epoch 93/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 7.6911e-04 - learning_rate: 0.0010
# Epoch 94/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 7.5917e-04 - learning_rate: 0.0010
# Epoch 95/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 7.4944e-04 - learning_rate: 0.0010
# Epoch 96/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 7.3994e-04 - learning_rate: 0.0010
# Epoch 97/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 7.3063e-04 - learning_rate: 0.0010
# Epoch 98/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 7.2155e-04 - learning_rate: 0.0010
# Epoch 99/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 7.1263e-04 - learning_rate: 0.0010
# Epoch 100/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 7.0389e-04 - learning_rate: 0.0010
# Epoch 101/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 6.9537e-04 - learning_rate: 0.0010
# Epoch 102/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 6.8699e-04 - learning_rate: 0.0010
# Epoch 103/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 6.7879e-04 - learning_rate: 0.0010
# Epoch 104/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 6.7076e-04 - learning_rate: 0.0010
# Epoch 105/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 6.6288e-04 - learning_rate: 0.0010
# Epoch 106/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 6.5514e-04 - learning_rate: 0.0010
# Epoch 107/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 6.4757e-04 - learning_rate: 0.0010
# Epoch 108/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 6.4015e-04 - learning_rate: 0.0010
# Epoch 109/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 6.3286e-04 - learning_rate: 0.0010
# Epoch 110/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 6.2569e-04 - learning_rate: 0.0010
# Epoch 111/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 6.1866e-04 - learning_rate: 0.0010
# Epoch 112/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 6.1176e-04 - learning_rate: 0.0010
# Epoch 113/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 6.0497e-04 - learning_rate: 0.0010
# Epoch 114/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 5.9831e-04 - learning_rate: 0.0010
# Epoch 115/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 5.9176e-04 - learning_rate: 0.0010
# Epoch 116/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 5.8532e-04 - learning_rate: 0.0010
# Epoch 117/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 5.7900e-04 - learning_rate: 0.0010
# Epoch 118/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 5.7279e-04 - learning_rate: 0.0010
# Epoch 119/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 5.6668e-04 - learning_rate: 0.0010
# Epoch 120/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 5.6069e-04 - learning_rate: 0.0010
# Epoch 121/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 5.5480e-04 - learning_rate: 0.0010
# Epoch 122/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 5.4901e-04 - learning_rate: 0.0010
# Epoch 123/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 5.4330e-04 - learning_rate: 0.0010
# Epoch 124/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 5.3772e-04 - learning_rate: 0.0010
# Epoch 125/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 5.3223e-04 - learning_rate: 0.0010
# Epoch 126/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 5.2681e-04 - learning_rate: 0.0010
# Epoch 127/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 5.2149e-04 - learning_rate: 0.0010
# Epoch 128/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 5.1625e-04 - learning_rate: 0.0010
# Epoch 129/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 5.1111e-04 - learning_rate: 0.0010
# Epoch 130/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 5.0606e-04 - learning_rate: 0.0010
# Epoch 131/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 5.0108e-04 - learning_rate: 0.0010
# Epoch 132/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 4.9618e-04 - learning_rate: 0.0010
# Epoch 133/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 4.9137e-04 - learning_rate: 0.0010
# Epoch 134/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 4.8664e-04 - learning_rate: 0.0010
# Epoch 135/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 4.8198e-04 - learning_rate: 0.0010
# Epoch 136/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 4.7739e-04 - learning_rate: 0.0010
# Epoch 137/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 4.7287e-04 - learning_rate: 0.0010
# Epoch 138/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 4.6843e-04 - learning_rate: 0.0010
# Epoch 139/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 4.6404e-04 - learning_rate: 0.0010
# Epoch 140/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 4.5973e-04 - learning_rate: 0.0010
# Epoch 141/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 4.5549e-04 - learning_rate: 0.0010
# Epoch 142/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 4.5129e-04 - learning_rate: 0.0010
# Epoch 143/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 4.4717e-04 - learning_rate: 0.0010
# Epoch 144/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 4.4311e-04 - learning_rate: 0.0010
# Epoch 145/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 4.3909e-04 - learning_rate: 0.0010
# Epoch 146/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 4.3515e-04 - learning_rate: 0.0010
# Epoch 147/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 4.3126e-04 - learning_rate: 0.0010
# Epoch 148/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 4.2743e-04 - learning_rate: 0.0010
# Epoch 149/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 4.2366e-04 - learning_rate: 0.0010
# Epoch 150/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 4.1993e-04 - learning_rate: 0.0010
# Epoch 151/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 4.1626e-04 - learning_rate: 0.0010
# Epoch 152/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 4.1265e-04 - learning_rate: 0.0010
# Epoch 153/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 4.0908e-04 - learning_rate: 0.0010
# Epoch 154/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 4.0556e-04 - learning_rate: 0.0010
# Epoch 155/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 4.0209e-04 - learning_rate: 0.0010
# Epoch 156/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 3.9865e-04 - learning_rate: 0.0010
# Epoch 157/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 3.9528e-04 - learning_rate: 0.0010
# Epoch 158/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 3.9195e-04 - learning_rate: 0.0010
# Epoch 159/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 3.8866e-04 - learning_rate: 0.0010
# Epoch 160/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 3.8541e-04 - learning_rate: 0.0010
# Epoch 161/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 3.8221e-04 - learning_rate: 0.0010
# Epoch 162/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 3.7905e-04 - learning_rate: 0.0010
# Epoch 163/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 3.7594e-04 - learning_rate: 0.0010
# Epoch 164/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 3.7285e-04 - learning_rate: 0.0010
# Epoch 165/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 3.6982e-04 - learning_rate: 0.0010
# Epoch 166/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 3.6682e-04 - learning_rate: 0.0010
# Epoch 167/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 3.6385e-04 - learning_rate: 0.0010
# Epoch 168/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 3.6093e-04 - learning_rate: 0.0010
# Epoch 169/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 3.5805e-04 - learning_rate: 0.0010
# Epoch 170/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 3.5522e-04 - learning_rate: 0.0010
# Epoch 171/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 3.5240e-04 - learning_rate: 0.0010
# Epoch 172/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 3.4962e-04 - learning_rate: 0.0010
# Epoch 173/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 3.4688e-04 - learning_rate: 0.0010
# Epoch 174/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 3.4417e-04 - learning_rate: 0.0010
# Epoch 175/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 3.4150e-04 - learning_rate: 0.0010
# Epoch 176/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 3.3887e-04 - learning_rate: 0.0010
# Epoch 177/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 3.3626e-04 - learning_rate: 0.0010
# Epoch 178/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 3.3368e-04 - learning_rate: 0.0010
# Epoch 179/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 3.3112e-04 - learning_rate: 0.0010
# Epoch 180/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 3.2861e-04 - learning_rate: 0.0010
# Epoch 181/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 3.2612e-04 - learning_rate: 0.0010
# Epoch 182/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 3.2366e-04 - learning_rate: 0.0010
# Epoch 183/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 3.2123e-04 - learning_rate: 0.0010
# Epoch 184/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 3.1883e-04 - learning_rate: 0.0010
# Epoch 185/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 3.1647e-04 - learning_rate: 0.0010
# Epoch 186/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 3.1413e-04 - learning_rate: 0.0010
# Epoch 187/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 3.1182e-04 - learning_rate: 0.0010
# Epoch 188/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 3.0953e-04 - learning_rate: 0.0010
# Epoch 189/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 3.0727e-04 - learning_rate: 0.0010
# Epoch 190/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 3.0503e-04 - learning_rate: 0.0010
# Epoch 191/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 3.0283e-04 - learning_rate: 0.0010
# Epoch 192/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 3.0065e-04 - learning_rate: 0.0010
# Epoch 193/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 2.9848e-04 - learning_rate: 0.0010
# Epoch 194/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 2.9635e-04 - learning_rate: 0.0010
# Epoch 195/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 2.9424e-04 - learning_rate: 0.0010
# Epoch 196/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 2.9216e-04 - learning_rate: 0.0010
# Epoch 197/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 2.9009e-04 - learning_rate: 0.0010
# Epoch 198/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 2.8804e-04 - learning_rate: 0.0010
# Epoch 199/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 2.8603e-04 - learning_rate: 0.0010
# Epoch 200/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 2.8404e-04 - learning_rate: 0.0010
# Epoch 201/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 2.8205e-04 - learning_rate: 0.0010
# Epoch 202/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 2.8010e-04 - learning_rate: 0.0010
# Epoch 203/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 2.7815e-04 - learning_rate: 0.0010
# Epoch 204/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 2.7625e-04 - learning_rate: 0.0010
# Epoch 205/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 2.7435e-04 - learning_rate: 0.0010
# Epoch 206/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 2.7247e-04 - learning_rate: 0.0010
# Epoch 207/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 2.7061e-04 - learning_rate: 0.0010
# Epoch 208/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 2.6879e-04 - learning_rate: 0.0010
# Epoch 209/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 2.6696e-04 - learning_rate: 0.0010
# Epoch 210/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 2.6516e-04 - learning_rate: 0.0010
# Epoch 211/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 2.6339e-04 - learning_rate: 0.0010
# Epoch 212/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 2.6163e-04 - learning_rate: 0.0010
# Epoch 213/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 2.5988e-04 - learning_rate: 0.0010
# Epoch 214/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 2.5816e-04 - learning_rate: 0.0010
# Epoch 215/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 2.5645e-04 - learning_rate: 0.0010
# Epoch 216/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 2.5475e-04 - learning_rate: 0.0010
# Epoch 217/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 2.5309e-04 - learning_rate: 0.0010
# Epoch 218/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 2.5143e-04 - learning_rate: 0.0010
# Epoch 219/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 2.4978e-04 - learning_rate: 0.0010
# Epoch 220/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 2.4817e-04 - learning_rate: 0.0010
# Epoch 221/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 2.4655e-04 - learning_rate: 0.0010
# Epoch 222/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 2.4496e-04 - learning_rate: 0.0010
# Epoch 223/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 2.4338e-04 - learning_rate: 0.0010
# Epoch 224/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 2.4181e-04 - learning_rate: 0.0010
# Epoch 225/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 2.4027e-04 - learning_rate: 0.0010
# Epoch 226/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 2.3874e-04 - learning_rate: 0.0010
# Epoch 227/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 2.3723e-04 - learning_rate: 0.0010
# Epoch 228/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 2.3572e-04 - learning_rate: 0.0010
# Epoch 229/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 2.3424e-04 - learning_rate: 0.0010
# Epoch 230/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 2.3276e-04 - learning_rate: 0.0010
# Epoch 231/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 2.3131e-04 - learning_rate: 0.0010
# Epoch 232/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 2.2986e-04 - learning_rate: 0.0010
# Epoch 233/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 2.2845e-04 - learning_rate: 0.0010
# Epoch 234/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 2.2701e-04 - learning_rate: 0.0010
# Epoch 235/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 2.2561e-04 - learning_rate: 0.0010
# Epoch 236/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 2.2422e-04 - learning_rate: 0.0010
# Epoch 237/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 2.2284e-04 - learning_rate: 0.0010
# Epoch 238/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 2.2147e-04 - learning_rate: 0.0010
# Epoch 239/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 2.2011e-04 - learning_rate: 0.0010
# Epoch 240/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 2.1878e-04 - learning_rate: 0.0010
# Epoch 241/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 2.1744e-04 - learning_rate: 0.0010
# Epoch 242/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 2.1613e-04 - learning_rate: 0.0010
# Epoch 243/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 2.1481e-04 - learning_rate: 0.0010
# Epoch 244/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 2.1352e-04 - learning_rate: 0.0010
# Epoch 245/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 2.1224e-04 - learning_rate: 0.0010
# Epoch 246/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 2.1097e-04 - learning_rate: 0.0010
# Epoch 247/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 2.0971e-04 - learning_rate: 0.0010
# Epoch 248/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 2.0847e-04 - learning_rate: 0.0010
# Epoch 249/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 2.0723e-04 - learning_rate: 0.0010
# Epoch 250/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 2.0599e-04 - learning_rate: 0.0010
# Epoch 251/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 2.0478e-04 - learning_rate: 0.0010
# Epoch 252/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 2.0357e-04 - learning_rate: 0.0010
# Epoch 253/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 2.0236e-04 - learning_rate: 0.0010
# Epoch 254/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 2.0120e-04 - learning_rate: 0.0010
# Epoch 255/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 2.0003e-04 - learning_rate: 0.0010
# Epoch 256/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.9885e-04 - learning_rate: 0.0010
# Epoch 257/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.9771e-04 - learning_rate: 0.0010
# Epoch 258/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 1.9657e-04 - learning_rate: 0.0010
# Epoch 259/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.9543e-04 - learning_rate: 0.0010
# Epoch 260/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.9431e-04 - learning_rate: 0.0010
# Epoch 261/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.9320e-04 - learning_rate: 0.0010
# Epoch 262/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.9209e-04 - learning_rate: 0.0010
# Epoch 263/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.9100e-04 - learning_rate: 0.0010
# Epoch 264/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.8991e-04 - learning_rate: 0.0010
# Epoch 265/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 1.8883e-04 - learning_rate: 0.0010
# Epoch 266/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.8777e-04 - learning_rate: 0.0010
# Epoch 267/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 1.8671e-04 - learning_rate: 0.0010
# Epoch 268/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 1.8567e-04 - learning_rate: 0.0010
# Epoch 269/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.8462e-04 - learning_rate: 0.0010
# Epoch 270/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 1.8359e-04 - learning_rate: 0.0010
# Epoch 271/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.8258e-04 - learning_rate: 0.0010
# Epoch 272/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.8157e-04 - learning_rate: 0.0010
# Epoch 273/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.8055e-04 - learning_rate: 0.0010
# Epoch 274/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.7957e-04 - learning_rate: 0.0010
# Epoch 275/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.7859e-04 - learning_rate: 0.0010
# Epoch 276/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.7767e-04 - learning_rate: 5.0000e-04
# Epoch 277/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 1.7720e-04 - learning_rate: 5.0000e-04
# Epoch 278/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 1.7672e-04 - learning_rate: 5.0000e-04
# Epoch 279/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.7622e-04 - learning_rate: 5.0000e-04
# Epoch 280/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 1.7574e-04 - learning_rate: 5.0000e-04
# Epoch 281/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 1.7526e-04 - learning_rate: 5.0000e-04
# Epoch 282/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.7479e-04 - learning_rate: 5.0000e-04
# Epoch 283/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.7431e-04 - learning_rate: 5.0000e-04
# Epoch 284/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 1.7383e-04 - learning_rate: 5.0000e-04
# Epoch 285/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.7337e-04 - learning_rate: 5.0000e-04
# Epoch 286/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 1.7289e-04 - learning_rate: 5.0000e-04
# Epoch 287/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.7242e-04 - learning_rate: 5.0000e-04
# Epoch 288/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.7195e-04 - learning_rate: 5.0000e-04
# Epoch 289/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 1.7149e-04 - learning_rate: 5.0000e-04
# Epoch 290/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.7102e-04 - learning_rate: 5.0000e-04
# Epoch 291/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.7055e-04 - learning_rate: 5.0000e-04
# Epoch 292/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 1.7009e-04 - learning_rate: 5.0000e-04
# Epoch 293/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.6963e-04 - learning_rate: 5.0000e-04
# Epoch 294/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 1.6918e-04 - learning_rate: 5.0000e-04
# Epoch 295/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 1.6872e-04 - learning_rate: 5.0000e-04
# Epoch 296/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.6825e-04 - learning_rate: 5.0000e-04
# Epoch 297/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.6780e-04 - learning_rate: 5.0000e-04
# Epoch 298/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 1.6734e-04 - learning_rate: 5.0000e-04
# Epoch 299/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.6689e-04 - learning_rate: 5.0000e-04
# Epoch 300/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.6643e-04 - learning_rate: 5.0000e-04
# Epoch 301/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.6599e-04 - learning_rate: 5.0000e-04
# Epoch 302/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 1.6553e-04 - learning_rate: 5.0000e-04
# Epoch 303/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.6508e-04 - learning_rate: 5.0000e-04
# Epoch 304/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 1.6464e-04 - learning_rate: 5.0000e-04
# Epoch 305/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.6419e-04 - learning_rate: 5.0000e-04
# Epoch 306/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.6375e-04 - learning_rate: 5.0000e-04
# Epoch 307/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 1.6329e-04 - learning_rate: 5.0000e-04
# Epoch 308/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.6286e-04 - learning_rate: 5.0000e-04
# Epoch 309/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 1.6242e-04 - learning_rate: 5.0000e-04
# Epoch 310/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 1.6198e-04 - learning_rate: 5.0000e-04
# Epoch 311/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.6154e-04 - learning_rate: 5.0000e-04
# Epoch 312/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 1.6111e-04 - learning_rate: 5.0000e-04
# Epoch 313/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.6066e-04 - learning_rate: 5.0000e-04
# Epoch 314/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.6022e-04 - learning_rate: 5.0000e-04
# Epoch 315/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 1.5979e-04 - learning_rate: 5.0000e-04
# Epoch 316/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.5937e-04 - learning_rate: 5.0000e-04
# Epoch 317/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 1.5893e-04 - learning_rate: 5.0000e-04
# Epoch 318/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 1.5849e-04 - learning_rate: 5.0000e-04
# Epoch 319/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.5807e-04 - learning_rate: 5.0000e-04
# Epoch 320/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 1.5764e-04 - learning_rate: 5.0000e-04
# Epoch 321/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 1.5722e-04 - learning_rate: 5.0000e-04
# Epoch 322/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.5680e-04 - learning_rate: 5.0000e-04
# Epoch 323/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.5638e-04 - learning_rate: 5.0000e-04
# Epoch 324/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 1.5595e-04 - learning_rate: 5.0000e-04
# Epoch 325/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.5553e-04 - learning_rate: 5.0000e-04
# Epoch 326/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 1.5513e-04 - learning_rate: 2.5000e-04
# Epoch 327/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.5494e-04 - learning_rate: 2.5000e-04
# Epoch 328/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.5472e-04 - learning_rate: 2.5000e-04
# Epoch 329/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 1.5451e-04 - learning_rate: 2.5000e-04
# Epoch 330/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 1.5430e-04 - learning_rate: 2.5000e-04
# Epoch 331/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.5410e-04 - learning_rate: 2.5000e-04
# Epoch 332/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.5388e-04 - learning_rate: 2.5000e-04
# Epoch 333/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.5367e-04 - learning_rate: 2.5000e-04
# Epoch 334/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.5347e-04 - learning_rate: 2.5000e-04
# Epoch 335/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 1.5327e-04 - learning_rate: 2.5000e-04
# Epoch 336/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.5306e-04 - learning_rate: 2.5000e-04
# Epoch 337/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.5284e-04 - learning_rate: 2.5000e-04
# Epoch 338/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 1.5264e-04 - learning_rate: 2.5000e-04
# Epoch 339/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.5242e-04 - learning_rate: 2.5000e-04
# Epoch 340/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.5222e-04 - learning_rate: 2.5000e-04
# Epoch 341/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.5201e-04 - learning_rate: 2.5000e-04
# Epoch 342/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.5180e-04 - learning_rate: 2.5000e-04
# Epoch 343/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 1.5158e-04 - learning_rate: 2.5000e-04
# Epoch 344/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 1.5138e-04 - learning_rate: 2.5000e-04
# Epoch 345/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 1.5118e-04 - learning_rate: 2.5000e-04
# Epoch 346/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.5098e-04 - learning_rate: 2.5000e-04
# Epoch 347/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 1.5077e-04 - learning_rate: 2.5000e-04
# Epoch 348/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 1.5055e-04 - learning_rate: 2.5000e-04
# Epoch 349/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.5035e-04 - learning_rate: 2.5000e-04
# Epoch 350/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 1.5013e-04 - learning_rate: 2.5000e-04
# Epoch 351/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 1.4993e-04 - learning_rate: 2.5000e-04
# Epoch 352/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.4972e-04 - learning_rate: 2.5000e-04
# Epoch 353/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 1.4951e-04 - learning_rate: 2.5000e-04
# Epoch 354/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.4931e-04 - learning_rate: 2.5000e-04
# Epoch 355/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.4911e-04 - learning_rate: 2.5000e-04
# Epoch 356/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.4890e-04 - learning_rate: 2.5000e-04
# Epoch 357/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 1.4868e-04 - learning_rate: 2.5000e-04
# Epoch 358/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.4848e-04 - learning_rate: 2.5000e-04
# Epoch 359/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.4827e-04 - learning_rate: 2.5000e-04
# Epoch 360/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.4807e-04 - learning_rate: 2.5000e-04
# Epoch 361/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.4786e-04 - learning_rate: 2.5000e-04
# Epoch 362/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 1.4765e-04 - learning_rate: 2.5000e-04
# Epoch 363/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.4745e-04 - learning_rate: 2.5000e-04
# Epoch 364/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.4725e-04 - learning_rate: 2.5000e-04
# Epoch 365/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 1.4704e-04 - learning_rate: 2.5000e-04
# Epoch 366/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.4683e-04 - learning_rate: 2.5000e-04
# Epoch 367/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.4664e-04 - learning_rate: 2.5000e-04
# Epoch 368/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 1.4641e-04 - learning_rate: 2.5000e-04
# Epoch 369/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.4621e-04 - learning_rate: 2.5000e-04
# Epoch 370/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 1.4602e-04 - learning_rate: 2.5000e-04
# Epoch 371/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 1.4581e-04 - learning_rate: 2.5000e-04
# Epoch 372/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.4560e-04 - learning_rate: 2.5000e-04
# Epoch 373/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.4539e-04 - learning_rate: 2.5000e-04
# Epoch 374/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.4519e-04 - learning_rate: 2.5000e-04
# Epoch 375/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.4498e-04 - learning_rate: 2.5000e-04
# Epoch 376/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.4479e-04 - learning_rate: 1.2500e-04
# Epoch 377/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 1.4470e-04 - learning_rate: 1.2500e-04
# Epoch 378/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.4459e-04 - learning_rate: 1.2500e-04
# Epoch 379/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 1.4448e-04 - learning_rate: 1.2500e-04
# Epoch 380/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 1.4438e-04 - learning_rate: 1.2500e-04
# Epoch 381/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.4428e-04 - learning_rate: 1.2500e-04
# Epoch 382/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.4417e-04 - learning_rate: 1.2500e-04
# Epoch 383/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 1.4407e-04 - learning_rate: 1.2500e-04
# Epoch 384/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.4397e-04 - learning_rate: 1.2500e-04
# Epoch 385/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.4386e-04 - learning_rate: 1.2500e-04
# Epoch 386/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.4376e-04 - learning_rate: 1.2500e-04
# Epoch 387/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.4366e-04 - learning_rate: 1.2500e-04
# Epoch 388/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 1.4356e-04 - learning_rate: 1.2500e-04
# Epoch 389/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.4345e-04 - learning_rate: 1.2500e-04
# Epoch 390/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.4335e-04 - learning_rate: 1.2500e-04
# Epoch 391/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.4325e-04 - learning_rate: 1.2500e-04
# Epoch 392/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 1.4316e-04 - learning_rate: 1.2500e-04
# Epoch 393/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.4303e-04 - learning_rate: 1.2500e-04
# Epoch 394/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.4295e-04 - learning_rate: 1.2500e-04
# Epoch 395/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.4284e-04 - learning_rate: 1.2500e-04
# Epoch 396/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.4274e-04 - learning_rate: 1.2500e-04
# Epoch 397/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 1.4263e-04 - learning_rate: 1.2500e-04
# Epoch 398/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 1.4253e-04 - learning_rate: 1.2500e-04
# Epoch 399/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.4243e-04 - learning_rate: 1.2500e-04
# Epoch 400/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.4232e-04 - learning_rate: 1.2500e-04
# Epoch 401/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 1.4221e-04 - learning_rate: 1.2500e-04
# Epoch 402/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 1.4212e-04 - learning_rate: 1.2500e-04
# Epoch 403/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.4201e-04 - learning_rate: 1.2500e-04
# Epoch 404/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.4190e-04 - learning_rate: 1.2500e-04
# Epoch 405/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 1.4180e-04 - learning_rate: 1.2500e-04
# Epoch 406/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.4169e-04 - learning_rate: 1.2500e-04
# Epoch 407/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 1.4159e-04 - learning_rate: 1.2500e-04
# Epoch 408/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.4149e-04 - learning_rate: 1.2500e-04
# Epoch 409/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.4137e-04 - learning_rate: 1.2500e-04
# Epoch 410/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.4128e-04 - learning_rate: 1.2500e-04
# Epoch 411/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.4117e-04 - learning_rate: 1.2500e-04
# Epoch 412/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 1.4107e-04 - learning_rate: 1.2500e-04
# Epoch 413/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.4097e-04 - learning_rate: 1.2500e-04
# Epoch 414/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 1.4085e-04 - learning_rate: 1.2500e-04
# Epoch 415/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 1.4074e-04 - learning_rate: 1.2500e-04
# Epoch 416/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 1.4064e-04 - learning_rate: 1.2500e-04
# Epoch 417/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 1.4053e-04 - learning_rate: 1.2500e-04
# Epoch 418/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.4043e-04 - learning_rate: 1.2500e-04
# Epoch 419/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.4033e-04 - learning_rate: 1.2500e-04
# Epoch 420/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.4021e-04 - learning_rate: 1.2500e-04
# Epoch 421/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 1.4011e-04 - learning_rate: 1.2500e-04
# Epoch 422/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.4002e-04 - learning_rate: 1.2500e-04
# Epoch 423/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 1.3990e-04 - learning_rate: 1.2500e-04
# Epoch 424/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.3980e-04 - learning_rate: 1.2500e-04
# Epoch 425/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.3969e-04 - learning_rate: 1.2500e-04
# Epoch 426/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.3958e-04 - learning_rate: 1.2500e-04
# Epoch 427/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.3948e-04 - learning_rate: 1.2500e-04
# Epoch 428/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.3939e-04 - learning_rate: 1.2500e-04
# Epoch 429/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 1.3927e-04 - learning_rate: 1.2500e-04
# Epoch 430/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 1.3916e-04 - learning_rate: 1.2500e-04
# Epoch 431/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.3906e-04 - learning_rate: 1.2500e-04
# Epoch 432/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.3895e-04 - learning_rate: 1.2500e-04
# Epoch 433/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.3884e-04 - learning_rate: 1.2500e-04
# Epoch 434/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.3873e-04 - learning_rate: 1.2500e-04
# Epoch 435/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.3863e-04 - learning_rate: 1.2500e-04
# Epoch 436/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 1.3853e-04 - learning_rate: 1.2500e-04
# Epoch 437/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.3841e-04 - learning_rate: 1.2500e-04
# Epoch 438/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 1.3831e-04 - learning_rate: 1.2500e-04
# Epoch 439/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 1.3820e-04 - learning_rate: 1.2500e-04
# Epoch 440/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.3810e-04 - learning_rate: 1.2500e-04
# Epoch 441/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 1.3800e-04 - learning_rate: 1.2500e-04
# Epoch 442/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.3788e-04 - learning_rate: 1.2500e-04
# Epoch 443/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 1.3777e-04 - learning_rate: 1.2500e-04
# Epoch 444/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.3768e-04 - learning_rate: 1.2500e-04
# Epoch 445/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.3756e-04 - learning_rate: 1.2500e-04
# Epoch 446/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.3745e-04 - learning_rate: 1.2500e-04
# Epoch 447/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 1.3735e-04 - learning_rate: 1.2500e-04
# Epoch 448/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 1.3724e-04 - learning_rate: 1.2500e-04
# Epoch 449/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.3714e-04 - learning_rate: 1.2500e-04
# Epoch 450/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.3703e-04 - learning_rate: 1.2500e-04
# Epoch 451/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 1.3693e-04 - learning_rate: 1.2500e-04
# Epoch 452/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 1.3682e-04 - learning_rate: 1.2500e-04
# Epoch 453/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 1.3670e-04 - learning_rate: 1.2500e-04
# Epoch 454/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 1.3661e-04 - learning_rate: 1.2500e-04
# Epoch 455/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.3650e-04 - learning_rate: 1.2500e-04
# Epoch 456/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.3639e-04 - learning_rate: 1.2500e-04
# Epoch 457/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 1.3628e-04 - learning_rate: 1.2500e-04
# Epoch 458/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 1.3617e-04 - learning_rate: 1.2500e-04
# Epoch 459/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.3606e-04 - learning_rate: 1.2500e-04
# Epoch 460/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 1.3595e-04 - learning_rate: 1.2500e-04
# Epoch 461/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 1.3585e-04 - learning_rate: 1.2500e-04
# Epoch 462/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.3574e-04 - learning_rate: 1.2500e-04
# Epoch 463/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.3562e-04 - learning_rate: 1.2500e-04
# Epoch 464/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.3552e-04 - learning_rate: 1.2500e-04
# Epoch 465/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.3541e-04 - learning_rate: 1.2500e-04
# Epoch 466/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.3530e-04 - learning_rate: 1.2500e-04
# Epoch 467/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 1.3520e-04 - learning_rate: 1.2500e-04
# Epoch 468/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 1.3509e-04 - learning_rate: 1.2500e-04
# Epoch 469/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.3498e-04 - learning_rate: 1.2500e-04
# Epoch 470/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 1.3488e-04 - learning_rate: 1.2500e-04
# Epoch 471/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 1.3477e-04 - learning_rate: 1.0000e-04
# Epoch 472/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.3468e-04 - learning_rate: 1.0000e-04
# Epoch 473/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 1.3459e-04 - learning_rate: 1.0000e-04
# Epoch 474/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 1.3451e-04 - learning_rate: 1.0000e-04
# Epoch 475/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 1.3443e-04 - learning_rate: 1.0000e-04
# Epoch 476/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.3434e-04 - learning_rate: 1.0000e-04
# Epoch 477/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 1.3423e-04 - learning_rate: 1.0000e-04
# Epoch 478/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.3416e-04 - learning_rate: 1.0000e-04
# Epoch 479/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.3407e-04 - learning_rate: 1.0000e-04
# Epoch 480/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 1.3400e-04 - learning_rate: 1.0000e-04
# Epoch 481/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.3390e-04 - learning_rate: 1.0000e-04
# Epoch 482/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 1.3380e-04 - learning_rate: 1.0000e-04
# Epoch 483/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 1.3373e-04 - learning_rate: 1.0000e-04
# Epoch 484/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 1.3363e-04 - learning_rate: 1.0000e-04
# Epoch 485/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 1.3355e-04 - learning_rate: 1.0000e-04
# Epoch 486/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.3347e-04 - learning_rate: 1.0000e-04
# Epoch 487/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 1.3338e-04 - learning_rate: 1.0000e-04
# Epoch 488/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 1.3329e-04 - learning_rate: 1.0000e-04
# Epoch 489/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 1.3320e-04 - learning_rate: 1.0000e-04
# Epoch 490/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.3311e-04 - learning_rate: 1.0000e-04
# Epoch 491/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 1.3303e-04 - learning_rate: 1.0000e-04
# Epoch 492/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 1.3294e-04 - learning_rate: 1.0000e-04
# Epoch 493/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.3287e-04 - learning_rate: 1.0000e-04
# Epoch 494/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 1.3276e-04 - learning_rate: 1.0000e-04
# Epoch 495/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 1.3266e-04 - learning_rate: 1.0000e-04
# Epoch 496/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.3258e-04 - learning_rate: 1.0000e-04
# Epoch 497/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 1.3250e-04 - learning_rate: 1.0000e-04
# Epoch 498/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 1.3241e-04 - learning_rate: 1.0000e-04
# Epoch 499/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 1.3233e-04 - learning_rate: 1.0000e-04
# Epoch 500/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 1.3224e-04 - learning_rate: 1.0000e-04
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 0.85

# %%
import matplotlib.pyplot as plt

# you can retrieve the history of training to visualize the loss
loss = cnn_cls.history.history["loss"]
plt.plot(loss, color='blue')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Evolution of the training loss.")
plt.show()

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

cnn_best = tf.keras.models.load_model("best_cnn.keras", compile=False)
# Out:
# [<InputLayer name=input_layer_3, built=True>,
#  <Conv1D name=conv1d_3, built=True>,
#  <BatchNormalization name=batch_normalization_3, built=True>,
#  <Activation name=activation_3, built=True>,
#  <Conv1D name=conv1d_4, built=True>,
#  <BatchNormalization name=batch_normalization_4, built=True>,
#  <Activation name=activation_4, built=True>,
#  <Conv1D name=conv1d_5, built=True>,
#  <BatchNormalization name=batch_normalization_5, built=True>,
#  <Activation name=activation_5, built=True>,
#  <GlobalAveragePooling1D name=global_average_pooling1d_1, built=True>,
#  <Dense name=dense_9, built=True>]

# %%
#get conv weights of layer 1  
conv1_weights = cnn_best.layers[1].get_weights()[0]

#get conv weights of layer 2  
conv2_weights = cnn_best.layers[4].get_weights()[0]

fig,ax = plt.subplots(2,6,figsize=(20,7))

cmap = plt.get_cmap('tab20c')
values = np.linspace(0, 1, 18)
np.random.shuffle(values)

for i in range(6):
  ax[0,i].plot(conv1_weights[:,0,i],color=cmap(values[i]))
  ax[0,i].set_title('Conv layer 1, Filter ' + str(i+1))
  ax[1,i].plot(conv2_weights[:,0,i],color=cmap(values[6+i]))
  ax[1,i].set_title('Conv layer 2, Filter ' + str(i+1))
plt.tight_layout()
plt.show()

#os.remove("best_cnn.keras")

# %%
from aeon.regression.deep_learning import FCNRegressor
from sklearn.metrics import mean_squared_error

cnn_rgs = FCNRegressor(n_epochs=500)
cnn_rgs.fit(X_train_r, y_train_mtser)
cnn_rgs_preds = cnn_rgs.predict(X_test_r)
print(mean_squared_error(y_test_mtser, cnn_rgs_preds))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step
# 1.2391741678125805

# %%
from aeon.visualisation import plot_scatter_predictions

plot_scatter_predictions(y_test_mtser, cnn_rgs_preds, title="FCNRegressor Predictions")
# Out:
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'FCNRegressor Predictions'}, xlabel='Actual values', ylabel='Predicted values'>)

# %%
from aeon.classification.deep_learning import  TimeCNNClassifier
from sklearn.metrics import accuracy_score

# n_epochs chooses the number of training iterations
# verbose show the network's detail and the logs of training
cnn_cls = TimeCNNClassifier(n_epochs=500, verbose=True, save_best_model=True, best_file_name="best_time_cnn")
cnn_cls.fit(X_train_c, y_train_mtsc)
cnn_cls_preds = cnn_cls.predict(X_test_c)
print(accuracy_score(y_test_mtsc, cnn_cls_preds))
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 100, 4)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_9 (Conv1D)               │ (None, 94, 6)          │           174 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling1d               │ (None, 31, 6)          │             0 │
# │ (AveragePooling1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_10 (Conv1D)              │ (None, 25, 12)         │           516 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling1d_1             │ (None, 8, 12)          │             0 │
# │ (AveragePooling1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 96)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 2)              │           194 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 884 (3.45 KB)
#  Trainable params: 884 (3.45 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.5000 - loss: 0.2771
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5000 - loss: 0.2653
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5000 - loss: 0.2569
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5000 - loss: 0.2513
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5000 - loss: 0.2484
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6500 - loss: 0.2476
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5000 - loss: 0.2480
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5000 - loss: 0.2491
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5000 - loss: 0.2503
# Epoch 10/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5000 - loss: 0.2513
# Epoch 11/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5000 - loss: 0.2518
# Epoch 12/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5000 - loss: 0.2520
# Epoch 13/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5000 - loss: 0.2518
# Epoch 14/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5000 - loss: 0.2514
# Epoch 15/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5000 - loss: 0.2508
# Epoch 16/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5000 - loss: 0.2501
# Epoch 17/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5000 - loss: 0.2494
# Epoch 18/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5000 - loss: 0.2487
# Epoch 19/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5000 - loss: 0.2481
# Epoch 20/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5000 - loss: 0.2475
# Epoch 21/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5000 - loss: 0.2470
# Epoch 22/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5000 - loss: 0.2466
# Epoch 23/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5000 - loss: 0.2462
# Epoch 24/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5000 - loss: 0.2458
# Epoch 25/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5000 - loss: 0.2455
# Epoch 26/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5000 - loss: 0.2451
# Epoch 27/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5000 - loss: 0.2448
# Epoch 28/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5000 - loss: 0.2445
# Epoch 29/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5000 - loss: 0.2442
# Epoch 30/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5000 - loss: 0.2439
# Epoch 31/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5000 - loss: 0.2436
# Epoch 32/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5000 - loss: 0.2432
# Epoch 33/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5000 - loss: 0.2428
# Epoch 34/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5000 - loss: 0.2424
# Epoch 35/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5000 - loss: 0.2420
# Epoch 36/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5000 - loss: 0.2416
# Epoch 37/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5000 - loss: 0.2411
# Epoch 38/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5000 - loss: 0.2407
# Epoch 39/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.
500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0271
# Epoch 431/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0269
# Epoch 432/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0268
# Epoch 433/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0266
# Epoch 434/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0264
# Epoch 435/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0263
# Epoch 436/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0261
# Epoch 437/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0259
# Epoch 438/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0258
# Epoch 439/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0256
# Epoch 440/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0255
# Epoch 441/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0253
# Epoch 442/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0251
# Epoch 443/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0250
# Epoch 444/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0248
# Epoch 445/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0247
# Epoch 446/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0245
# Epoch 447/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0244
# Epoch 448/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0242
# Epoch 449/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0241
# Epoch 450/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0239
# Epoch 451/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0238
# Epoch 452/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0236
# Epoch 453/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0235
# Epoch 454/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0234
# Epoch 455/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0232
# Epoch 456/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0231
# Epoch 457/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0229
# Epoch 458/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0228
# Epoch 459/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0227
# Epoch 460/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0225
# Epoch 461/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0224
# Epoch 462/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0222
# Epoch 463/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0221
# Epoch 464/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0220
# Epoch 465/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0218
# Epoch 466/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0217
# Epoch 467/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0216
# Epoch 468/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0215
# Epoch 469/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0213
# Epoch 470/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0212
# Epoch 471/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0211
# Epoch 472/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0209
# Epoch 473/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0208
# Epoch 474/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0207
# Epoch 475/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0206
# Epoch 476/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0204
# Epoch 477/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0203
# Epoch 478/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0202
# Epoch 479/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0201
# Epoch 480/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0200
# Epoch 481/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0199
# Epoch 482/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0197
# Epoch 483/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0196
# Epoch 484/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0195
# Epoch 485/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0194
# Epoch 486/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0193
# Epoch 487/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0192
# Epoch 488/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0191
# Epoch 489/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0189
# Epoch 490/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0188
# Epoch 491/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0187
# Epoch 492/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0186
# Epoch 493/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0185
# Epoch 494/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0184
# Epoch 495/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0183
# Epoch 496/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0182
# Epoch 497/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0181
# Epoch 498/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0180
# Epoch 499/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0179
# Epoch 500/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0178
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 0.65

# %%
cnn_t_best = tf.keras.models.load_model("best_time_cnn.keras", compile=False)
cnn_t_best.layers
# Out:
# [<InputLayer name=input_layer_5, built=True>,
#  <Conv1D name=conv1d_9, built=True>,
#  <AveragePooling1D name=average_pooling1d, built=True>,
#  <Conv1D name=conv1d_10, built=True>,
#  <AveragePooling1D name=average_pooling1d_1, built=True>,
#  <Flatten name=flatten_2, built=True>,
#  <Dense name=dense_11, built=True>]

# %%
#get conv weights of layer 1  
conv1_weights = cnn_t_best.layers[1].get_weights()[0]

#get conv weights of layer 2  
conv2_weights = cnn_t_best.layers[3].get_weights()[0]

fig,ax = plt.subplots(2,6,figsize=(20,7))

cmap = plt.get_cmap('tab20c')
values = np.linspace(0, 1, 18)
np.random.shuffle(values)

for i in range(6):
  ax[0,i].plot(conv1_weights[:,0,i],color=cmap(values[i]))
  ax[0,i].set_title('Conv layer 1, Filter ' + str(i+1))
  ax[1,i].plot(conv2_weights[:,0,i],color=cmap(values[6+i]))
  ax[1,i].set_title('Conv layer 2, Filter ' + str(i+1))
plt.tight_layout()
plt.show()

#os.remove("best_cnn.keras")

# %%
from aeon.regression.deep_learning import  TimeCNNRegressor
from sklearn.metrics import mean_squared_error

cnn_rgs = TimeCNNRegressor(n_epochs=500)
cnn_rgs.fit(X_train_r, y_train_mtser)
cnn_rgs_preds = cnn_rgs.predict(X_test_r)
print(mean_squared_error(y_test_mtser, cnn_rgs_preds))

plot_scatter_predictions(y_test_mtser, cnn_rgs_preds, title="TimeCNNRegressor Predictions")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1.485700454367964
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'TimeCNNRegressor Predictions'}, xlabel='Actual values', ylabel='Predicted values'>)

# %% [markdown]
# # Упражнения <a id='tasks'></a>
#
# 1. Взять выбранные для лабы 9 набор(ы) данных. Можно взять разные наборы для классификации/регрессии (но причину надо будет обосновать)
#
# 2. Отрисовать данные
#
# 3. Попробовать все методы классификации и регрессии, описанные в блоноте:
#     Distance-based
#     Свертки (модели семейства Rocket и Hydra)
#     Feature-based
#     Deep Learning
#
#     Для каждого подхода обучть не менее 3х разных моделей для классификации и регрессии.

# %%
# load and plot data
from aeon.datasets import load_from_ts_file
import matplotlib.pyplot as plt

x_train, y_train = load_from_ts_file("./dataset/KDD_UTSC_TRAIN.ts", return_type="numpy2D")
x_test, y_test = load_from_ts_file("./dataset/KDD_UTSC_TEST.ts", return_type="numpy2D")

plt.plot(x_train[0])
plt.plot(x_train[1])
plt.show()

# %%
# distance-based models
from aeon.classification.distance_based import KNeighborsTimeSeriesClassifier, ElasticEnsemble, ProximityForest

knn = KNeighborsTimeSeriesClassifier(n_neighbors=3, distance="dtw")
knn.fit(x_train, y_train)
print(knn.score(x_test, y_test))

ee = ElasticEnsemble(proportion_of_param_options=0.1, proportion_train_for_test=0.5)
ee.fit(x_train, y_train)
print(ee.score(x_test, y_test))

pf = ProximityForest(n_trees=5)
pf.fit(x_train, y_train)
print(pf.score(x_test, y_test))
# Out:
# 0.55
# /home/bowie/repos/ts-magi-2025-2026/.venv/lib/python3.12/site-packages/sklearn/model_selection/_search.py:317: UserWarning: The total space of parameters 1 is smaller than n_iter=10. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# 0.5
# 0.5

# %%
# feature-based
from aeon.classification.feature_based import Catch22Classifier, FreshPRINCEClassifier, SummaryClassifier
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=10)

c22 = Catch22Classifier(estimator=rf)
c22.fit(x_train, y_train)
print(c22.score(x_test, y_test))

fp = FreshPRINCEClassifier(n_estimators=10)
fp.fit(x_train, y_train)
print(fp.score(x_test, y_test))

sc = SummaryClassifier(estimator=rf)
sc.fit(x_train, y_train)
print(sc.score(x_test, y_test))
# Out:
# 0.775
# 0.775
# 0.675

# %%
# deep learning
from aeon.classification.deep_learning import TimeCNNClassifier, FCNClassifier, MLPClassifier

cnn = TimeCNNClassifier(n_epochs=10)
cnn.fit(x_train, y_train)
print(cnn.score(x_test, y_test))

fcn = FCNClassifier(n_epochs=10)
fcn.fit(x_train, y_train)
print(fcn.score(x_test, y_test))

mlp = MLPClassifier(n_epochs=10)
mlp.fit(x_train, y_train)
print(mlp.score(x_test, y_test))
# Out:
# E0000 00:00:1774881872.117540   22250 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 0.5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 0.5
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x725684761b20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/stepWARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x725684761b20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 0.5
